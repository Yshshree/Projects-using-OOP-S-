# %%
#Emp Management Process using oop's concept

# %%
class Employee():
  empcount=0
  incmt=1.10

  def __init__(self,first,last,salary):
    self.first=first
    self.last=last
    self.salary=salary
    self.email=first.lower()+"."+last.lower()+"@quastech.com"
    Employee.empcount+=1
  def fullname(self):
    return f"{self.first.title()}{self.last.title()}"
  def increment(self):
    self.salary=int(self.salary*Employee.incmt)

# %%
emp1=Employee("saniya","shaikh",25000)
emp2=Employee("snehal","shinde",22000)
emp3=Employee("soham","malgunkar",34000)

# %%
emp2.email
# Out:
# 'snehal.shinde@quastech.com'

# %%
emp2.fullname()
# Out:
# 'SnehalShinde'

# %%
emp2.increment()
emp2.salary
# Out:
# 24200

# %%
class developer(Employee):
  def __init__(self,first,last,salary,prog_lang):
   super().__init__(first,last,salary)
   self.prog_lang=prog_lang

# %%
dev1=developer("abdul","shaikh",55000,"sql")
dev2=developer("yashshree","patil",45000,"php")

# %%
dev2.empcount
# Out:
# 5

# %%
dev2.email
# Out:
# 'yashshree.patil@quastech.com'

# %%
dev1.last
# Out:
# 'shaikh'

# %%
class manager(Employee):
  def __init__(self,first,last,salary,employees=None):
    super().__init__(first,last,salary)

    if(employees is None):
      self.employees=[]
    else:
      self.employees=employees=employees

  def addemp(self,emp):
      if emp not in self.employees:
        self.employees.append(emp)
  def removemp(self,emp):
      if emp in self.employees:
        self.employees.remove(emp)
  def print_emps(self):
      for emp in self.employees:
        print("-->",emp.fullname())

# %%
mgr1=manager("dhiraj","saroj",125000,[emp1,emp2,emp3])

# %%
mgr1.print_emps()
# Out:
# --> SaniyaShaikh
# --> SnehalShinde
# --> SohamMalgunkar
