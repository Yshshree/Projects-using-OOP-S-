# %%
class user():
  def __init__(self,name,age,gender):
    self.name=name
    self.age=age
    self.gender=gender
  def showdetails(self):
    print(f"personal detail")
    print(f"name :- {self.name.title()}")
    print(f"age :- {self.age}")
    print(f"gender :- {self.gender.title()}")

# %%
class bank(user):
  __balace=0
  __usercount=0
  def __init__(self,name,age,gender):
    super().__init__(name,age,gender)
    bank.__usercount += 1
    self.accountno=f"Denabank000{bank.__usercount}"
    self._balance = 0 # Initialize balance here

  def ud(self):
    return self.__usercount

  def deposite(self,amount):
    self.amount=amount
    self._balance +=self.amount
    print(f"account balance is updated:- rs.{self._balance}")

  def withdraw(self,amount):
    self.amount=amount

    if(self.amount>self._balance):
      print(f"insuffi amount,balance available:-  rs.{self._balance}")
    elif(100<=self.amount<=self._balance): # Corrected syntax
      print("Thank you for visiting")
      self._balance-=self.amount
      print(f"current balance is:- rs.{self._balance}")
    else:
      print(f"you cannot withdraw less than rd.100")

  def viewbalance(self):
    self.showdetails() # Corrected method call
    print(f"ac no:- {self.accountno}")
    print(f"current balance is:- {self._balance}")

  def transfer(self,username,amount):
    self.amount=amount
    if(self.amount>self._balance):
      print(f"insufficient amount,balance available:- rs{self._balance}")
    elif(1<=self.amount<=self._balance):
      username._balance +=self.amount
      self._balance -=self.amount
      print("amount transfered succefully")
      print(f"current balance is:- {self._balance}")
    else:
     print("you cannot transfer less then rs .1")

# %%
shree=bank("yashshree",24,"female")
shree.accountno
# Out:
# 'Denabank0001'

# %%
neha=bank("neha patil",23,"female")
manish=bank("manish patil",34,"male")

# %%
neha.deposite(25000)
# Out:
# account balance is updated:- rs.25000

# %%
manish.deposite(34000)
# Out:
# account balance is updated:- rs.34000

# %%
manish.transfer(neha,5000)
# Out:
# amount transfered succefully
# current balance is:- 29000

# %%
neha.viewbalance()
# Out:
# personal detail
# name :- Neha Patil
# age :- 23
# gender :- Female
# ac no:- Denabank0002
# current balance is:- 30000

# %%
manish.withdraw(20000)
# Out:
# Thank you for visiting
# current balance is:- rs.9000

# %%
class user():
  def __init__(self,name,age,gender):
    self.name=name
    self.age=age
    self.gender=gender
  def showdetails(self):
    print(f"personal detail")
    print(f"name :- {self.name.title()}")
    print(f"age :- {self.age}")
    print(f"gender :- {self.gender.title()}")

# %%
class bank(user):
  __balace=0
  __usercount=0
  def __init__(self,name,age,gender):
    super().__init__(name,age,gender)
    bank.__usercount += 1
    self.accountno=f"Denabank000{bank.__usercount}"
    self._balance = 0 # Initialize balance here

  def ud(self):
    return self.__usercount

  def deposite(self,amount):
    self.amount=amount
    self._balance +=self.amount
    print(f"account balance is updated:- rs.{self._balance}")

  def withdraw(self,amount):
    self.amount=amount

    if(self.amount>self._balance):
      print(f"insuffi amount,balance available:-  rs.{self._balance}")
    elif(100<=self.amount<=self._balance): # Corrected syntax
      print("Thank you for visiting")
      self._balance-=self.amount
      print(f"current balance is:- rs.{self._balance}")
    else:
      print(f"you cannot withdraw less than rd.100")

  def viewbalance(self):
    self.showdetails() # Corrected method call
    print(f"ac no:- {self.accountno}")
    print(f"current balance is:- {self._balance}")

  def transfer(self,username,amount):
    self.amount=amount
    if(self.amount>self._balance):
      print(f"insufficient amount,balance available:- rs{self._balance}")
    elif(1<=self.amount<=self._balance):
      username._balance +=self.amount
      self._balance -=self.amount
      print("amount transfered succefully")
      print(f"current balance is:- {self._balance}")
    else:
     print("you cannot transfer less then rs .1")

# %%
neha=bank("neha patil",23,"female")
manish=bank("manish patil",34,"male")

# %%
manish.withdraw(20000)
# Out:
# insuffi amount,balance available:-  rs.0

# %%
neha=bank("neha patil",23,"female")
manish=bank("manish patil",34,"male")

# %%
manish.withdraw(20000)
# Out:
# insuffi amount,balance available:-  rs.0
